# %%
import pandas


month = pandas.read_csv("gu/2010/Month.csv")
week = pandas.read_csv("gu/2010/Week.csv")
day = pandas.read_csv("gu/2010/Day.csv")
hour12 = pandas.read_csv("gu/2010/12hour.csv")
hour8 = pandas.read_csv("gu/2010/8hour.csv")
hour4 = pandas.read_csv("gu/2010/4hour.csv")
hour2 = pandas.read_csv("gu/2010/2hour.csv")
hour1 = pandas.read_csv("gu/2010/1hour.csv")
min45 = pandas.read_csv("gu/2010/45min.csv")
min30 = pandas.read_csv("gu/2010/30min.csv")
min15 = pandas.read_csv("gu/2010/15min.csv")
min5 = pandas.read_csv("gu/2010/5min.csv")

monthTickData= {}
weekTickData = {}
dayTickData = {}
hour12TickData = {}
hour8TickData = {}
hour4TickData={}
hour2TickData={}
hour1TickData={}
min45TickData={}
min30TickData={}
min15TickData={}
min5TickData={}

# for index, row in monthFile.iterrows():
#     print(row["Open"])

# Assign the row of the various timeframe into a data structure that can be easily manipulated
def monthData():
    
    for index, row in month.iterrows():
        monthTickData[row['Local time']] = {
            "open" : row['Open'],
            "high": row['High'],
            "low": row['Low'],
            "close": row['Close'],
            "volume": row['Volume']
        }
    # print(monthTickData)
    return monthTickData

def weekData():
    
    for index, row in week.iterrows():
        weekTickData[row['Local time']] = {
            "open" : row['Open'],
            "high": row['High'],
            "low": row['Low'],
            "close": row['Close'],
            "volume": row['Volume']
        }
    
    return weekTickData

def dayData():
    
    for index, row in day.iterrows():
        dayTickData[row['Local time']] = {
            "open" : row['Open'],
            "high": row['High'],
            "low": row['Low'],
            "close": row['Close'],
            "volume": row['Volume']
        }
    
    return dayTickData

def hour12Data():
    
    for index, row in hour12.iterrows():
        hour12TickData[row['Local time']] = {
            "open" : row['Open'],
            "high": row['High'],
            "low": row['Low'],
            "close": row['Close'],
            "volume": row['Volume']
        }
    
    return hour12TickData

def hour8Data():
    
    for index, row in hour8.iterrows():
        hour8TickData[row['Local time']] = {
            "open" : row['Open'],
            "high": row['High'],
            "low": row['Low'],
            "close": row['Close'],
            "volume": row['Volume']
        }
    
    return hour8TickData

def hour4Data():
    
    for index, row in hour4.iterrows():
        hour4TickData[row['Local time']] = {
            "open" : row['Open'],
            "high": row['High'],
            "low": row['Low'],
            "close": row['Close'],
            "volume": row['Volume']
        }
    
    return hour4TickData

def hour2Data():
    
    for index, row in hour2.iterrows():
        hour2TickData[row['Local time']] = {
            "open" : row['Open'],
            "high": row['High'],
            "low": row['Low'],
            "close": row['Close'],
            "volume": row['Volume']
        }
    
    return hour2TickData

def hour1Data():
    
    for index, row in hour1.iterrows():
        hour1TickData[row['Local time']] = {
            "open" : row['Open'],
            "high": row['High'],
            "low": row['Low'],
            "close": row['Close'],
            "volume": row['Volume']
        }
    
    return hour1TickData


def min45Data():
    
    for index, row in min45.iterrows():
        min45TickData[row['Local time']] = {
            "open" : row['Open'],
            "high": row['High'],
            "low": row['Low'],
            "close": row['Close'],
            "volume": row['Volume']
        }
    
    return min45TickData


def min30Data():
    
    for index, row in min30.iterrows():
        min30TickData[row['Local time']] = {
            "open" : row['Open'],
            "high": row['High'],
            "low": row['Low'],
            "close": row['Close'],
            "volume": row['Volume']
        }
    
    return min30TickData

def min15Data():
    
    for index, row in min15.iterrows():
        min15TickData[row['Local time']] = {
            "open" : row['Open'],
            "high": row['High'],
            "low": row['Low'],
            "close": row['Close'],
            "volume": row['Volume']
        }
    
    return min15TickData

def min5Data():
    
    for index, row in min5.iterrows():
        min5TickData[row['Local time']] = {
            "open" : row['Open'],
            "high": row['High'],
            "low": row['Low'],
            "close": row['Close'],
            "volume": row['Volume']
        }
    
    return min5TickData






monthTrend = {}
weekTrend = {}
hour12Trend = {}
hour8Trend ={}
hour4Trend = {}
hour2Trend ={}
hour1Trend = {}
min45Trend ={}
min30Trend ={}
min15Trend= {}
min5Trend = {}      


 
          


class Trend:
    
    def __init__(self) -> None:
        pass
    
    def trend(self, tickData, trendData):
        currTickHigh=0
        currTickLow=0 
        prevTickHigh=0
        prevTickLow = 0
        nextTickHigh = 0
        nextTickLow = 0
        
        for key, value in tickData.items():
            if(prevTickHigh == 0 or prevTickLow == 0):
                prevTickHigh = value["high"]
                prevTickLow = value["low"]
                
                trendData[key]={"high":prevTickHigh,
                                "low": prevTickLow,
                                "status":""}
            
                # print(trendData)
            elif((prevTickHigh != 0 and prevTickLow != 0) and ( currTickHigh == 0 and currTickLow == 0 )):
                currTickHigh = value["high"]
                currTickLow = value["low"]
                trendData[key]={"high":currTickHigh,
                                "low": currTickLow,
                                "status":""}
                
                print(trendData)
                # print(currTickHigh)
            elif((prevTickHigh != 0 and prevTickLow != 0) and (currTickHigh != 0 and currTickLow != 0)) and( nextTickHigh == 0 and nextTickLow == 0):
                nextTickHigh = value["high"]
                nextTickLow = value["low"]
                
                self.swingPoint(key,value, trendData)
                # self.swingPoint()
                # print(nextTickHigh)
                
                
                
            else:
                pass
            
    # If this is a swing point return a status swing high, swing low, 
    # Also return the trend status (Bullish, Bearish, Neutral)
    # Bullish criteria two consecutive Swing high that create new highs on a particular time frame
    # Bearish criteria two consecutive Swing Low that creates new lows on a particular time frame
    # Change of trend when the we get two consecutive change of swing points.  
    def swingPoint(self, key ,tickData, trendData):
        print(key)
        trendDataKey = list(trendData.keys())
        
        midSwingPoint = trendDataKey[-1]
        prevSwingPoint = trendDataKey[-2]
        
        
        # print(trendData)
        # print(midSwingPoint, prevSwingPoint)
        
        # Detect a swing high
        if(trendData[midSwingPoint]["high"] > tickData['high'] and trendData[midSwingPoint]["low"] > tickData['low']  and trendData[midSwingPoint]["high"] > trendData[prevSwingPoint]["high"] and trendData[midSwingPoint]["low"] >  trendData[prevSwingPoint]["low"] ):
        #    Check if the new swing high is higher than the previous one
        
            for swingKey in reversed(list(trendData.keys())):
                if (trendData[swingKey]['status'] == "SwingHigh" and trendData[swingKey]['high'] < tickData["high"]):
                    
                    trendData[key]= {
                        "high":tickData["high"],
                        "low":tickData["low"],
                        "status": "SwingHigh"
                    }
                    pass
            pass
        elif(trendData[midSwingPoint]["high"] < tickData['high']  and trendData[midSwingPoint]["low"] < tickData['low']  and trendData[midSwingPoint]["high"] < trendData[prevSwingPoint]["high"] and trendData[midSwingPoint]["low"] <  trendData[prevSwingPoint]["low"] ):
            # Check if the new swing lower is lower than the previous one
            
            for swingKey in reversed(list(trendData.keys())):
                
                if (trendData[swingKey]['status'] == "SwingLow" and trendData[swingKey]['low'] > tickData["low"]):
                    
                    trendData[key]= {
                        "high":tickData["high"],
                        "low":tickData["low"],
                        "status": "SwingLow"
                    }
                    pass
            
            pass
        else:
            pass 
        
        print(trendData)
    
    # def trendDirection(self, trendData)
        
        # Determine the trend and a change of trend
    def monthT(self):
        data = monthData()
        # for key, value in data.items():
            # print(value['open'])
        self.trend(data,monthTrend)
            
        
newData = Trend()  
newData.monthT()
# Out:
# {'31.01.2010 23:00:00.000 GMT+0100': {'high': 1.6069, 'low': 1.51515, 'status': ''}, '28.02.2010 23:00:00.000 GMT+0100': {'high': 1.53815, 'low': 1.47805, 'status': ''}}
# 31.03.2010 22:00:00.000 GMT+0100
# {'31.01.2010 23:00:00.000 GMT+0100': {'high': 1.6069, 'low': 1.51515, 'status': ''}, '28.02.2010 23:00:00.000 GMT+0100': {'high': 1.53815, 'low': 1.47805, 'status': ''}}
